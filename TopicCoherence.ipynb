# %% [markdown]
# <a href="https://colab.research.google.com/github/harikrishnareddymallavarapu/DeepAndNLP/blob/master/TopicCoherence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Topic Coherence

# %% [markdown]
# https://www.aclweb.org/anthology/D12-1087.pdf
#
# Methods for Topic Modelling
#
# - LDA and LSA have different coherence strength
# - LDA best learns descriptive topics
# - LSA is best at creating a compact semantic representation of documents and words in a corpus
# - Non-negative Matrix Factorization??
#
# It is generally difficult to know which method  is most useful for a given application in terms of extracting Topics
#
# - Latent Dirichlet Allocation
# - Latent Semantic Analysis with Singular Value Decomposition
# - Latent Semantic Analysis with Non-negative Matrix Factorization
# - Probabilistic Latent Semantic Analysis
#
# ## Evaluation Tasks
# - Grouping together similar words while separating unrelated words
# - Distinguishing between documents focusing on different concepts.

# %% [markdown]
# ##Latent Dirichlet Allocation

# %% [markdown]
# ##Latent Semantic Analysis
#
# - LSA-SVD and LSA-NMF, both are cosidered as topic models as they have been used in similar contexts such as distributional similarity and word sense induction

# %% [markdown]
# ##Singular Value Decomposition
#
# Singular Value Decomposition decomposes matrix M into three smaller matrices and minimizes Frobenius norm of M’s reconstruction error with the constraint that the rows of U and V are orthonormal eigenvectors
#
# M = U Σ VT

# %% [markdown]
# ##Non-negative Matrix Factorization

# %% [markdown]
# ##Topic Coherence
# - Topic Coherence measures score a single topic by
# measuring the degree of semantic similarity between
# high scoring words in the topic.
# - These measurements help distinguish between topics that are semantically interpretable topics and topics that are artifacts of statistical inference
#
# Below are the two coherence measures designed for LDA
#
# - The UCI measure (Newman et al., 2010)
# - The UMass measure (Mimno et al., 2011)
#
# Both measures compute the coherence of a topic as the sum of pairwise
# distributional similarity scores over the set of topic words, V . We generalize this as
#
# c
# , vj , )![image.png](data:image/png;base64,...)
